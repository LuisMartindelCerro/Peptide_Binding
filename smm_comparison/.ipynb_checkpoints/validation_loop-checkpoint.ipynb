# %%
import os
import subprocess
import math
from pathlib import Path
import shutil
import numpy as np
import random
import copy
from scipy.stats import pearsonr
from pprint import pprint
from argparse import ArgumentParser
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# --- Configuration ---
RDIR = "/home/luis_ubuntu/unixdir/Peptide_Binding/smm_comparison/"
DDIR = "/home/luis_ubuntu/unixdir/Peptide_Binding/Data"

#alleles = [
#    "A0101", "A0202", "A2402", "A3001", "A3101", "A6901",
#    "B0801", "B3501", "B4403", "B5801", "A0201", "A2301",
#    "A2403", "A3002", "A6801", "B0702", "B2705", "B4402", "B5701"
#]

alleles = [
    "B5801", "A0201", "A3101"
]

lambdas = [0.02, 0.08, 0.1]
epis = [0.01, 0.04, 0.08]
folds = range(4)

# %%
# --- Pearson correlation calculator ---
def pearson_from_pairs(pairs):
    n = len(pairs)
    if n == 0:
        return 0.0, float("inf")
    
    x = [p[0] for p in pairs]
    y = [p[1] for p in pairs]
    
    x0 = sum(x) / n
    y0 = sum(y) / n
    
    t = nx = ny = err = 0.0
    for i in range(n):
        dx = x[i] - x0
        dy = y[i] - y0
        t += dx * dy
        nx += dx * dx
        ny += dy * dy
        err += (x[i] - y[i]) ** 2
    
    if nx * ny == 0:
        pcc = 0.0
    else:
        pcc = t / math.sqrt(nx * ny)
    
    mse = err / n
    return pcc, mse

def make_and_enter(dir_path):
    path = Path(dir_path)
    path.mkdir(exist_ok=True)
    os.chdir(path)

def run_training_and_evaluation(RDIR, train_file, eval_file, mat_file, pred_file, _lambda, _epsilon):
    # Run training
    if not Path(mat_file).exists():
        with open(mat_file, "w") as fout:
            subprocess.run(
                [
                    "python", f"{RDIR}/smm_gradient_descent.py",
                    "-l", str(_lambda),
                    "-epi", str(_epsilon),
                    "-t", train_file
                ],
                stdout=fout,
                stderr=subprocess.DEVNULL,
                env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
            )

    # Run evaluation
    if not Path(pred_file).exists():
        with open(pred_file, "w") as fout:
            subprocess.run(
                [
                    "python", f"{RDIR}/pep2score.py",
                    "-mat", mat_file,
                    "-f", eval_file
                ],
                stdout=fout,
                stderr=subprocess.DEVNULL,
                env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
            )

def save_final_predictions(allele, best_lambda, best_epsilon):
    """
    Concatenates all .pred files from the best hyperparameter directory
    and writes the result into {allele}_final_predictions file.
    """
    pred_lines = []
    best_pred_dir = Path(f"l.{best_lambda}/epi.{best_epsilon}")

    # Collect lines from all .pred files, ignoring comments
    for pred_file in best_pred_dir.glob("*.pred"):
        with open(pred_file) as pf:
            for line in pf:
                if not line.startswith("#") and line.strip():
                    pred_lines.append(line)

    # Write to the output file in the parent directory
    output_file = f"{RDIR}/{allele}.res/{allele}_prediction"
    with open(output_file, "w") as final_out:
        final_out.writelines(pred_lines)

# %% [markdown]
# LOOP FOR UN-NESTED

# %%
os.chdir(RDIR)
# --- Main loop ---
for allele in alleles:
    best_pcc = -1000
    best_model = ""
    best_lambda = ""
    best_epsilon = ""

    make_and_enter(f"{allele}_unnested.res")

    for l in lambdas:
        make_and_enter(f"l.{l}")

        for epi in epis:
            make_and_enter(f"epi.{epi}")

            preds = []

            for n in folds:
                mat_file = f"mat.{n}"
                pred_file = f"c00{n}.pred"
                
                train_file = f"{DDIR}/{allele}/f00{n}"
                eval_file = f"{DDIR}/{allele}/c00{n}"

                # Run training and evalutation
                run_training_and_evaluation(RDIR, train_file, eval_file, mat_file=mat_file, pred_file=pred_file, _lambda=l, _epsilon=epi)

                # Parse predictions
                with open(pred_file) as pf:
                    for line in pf:
                        if "#" not in line and line.strip():
                            try:
                                parts = line.strip().split()
                                preds.append((float(parts[1]), float(parts[2])))
                            except:
                                continue

            # Compute PCC and MSE
            pcc, mse = pearson_from_pairs(preds)
            eval_output = f"{allele} lambda {l} epsilon {epi} PCC {pcc:.5f} MSE {mse:.5f}"
            print(eval_output)

            if pcc > best_pcc:
                best_pcc = pcc
                best_lambda = l
                best_epsilon = epi
                best_model = f"lambda {best_lambda} epsilon {best_epsilon}"

            os.chdir("..")  # up from epi.X

        os.chdir("..")  # up from l.X
    
    # Final result
    print("\nBest model for allele", allele,": ", best_model, "with correlation", f"{best_pcc:.5f}\n")

    # save_final_predictions(allele, best_lambda, best_epsilon)

    #pairs = []
    #with open(f"{allele}_prediction") as f:
    #    for line in f:
    #        parts = line.strip().split()
    #        try:
    #            x = float(parts[1])  # second column
    #            y = float(parts[2])  # third column
    #            pairs.append((x, y))
    #        except (IndexError, ValueError):
    #            continue
                
    #pcc, mse = pearson_from_pairs(pairs)
    #eval_output = f"Final prediciton for allele:{allele}; PCC {pcc:.5f} MSE {mse:.5f}"
    #print(eval_output)

    eval_file = f"{DDIR}/{allele}/c004"
    mat_files = [f"{RDIR}/{allele}_unnested.res/l.{best_lambda}/epi.{best_epsilon}/mat.{i}" for i in range(4)]
    pred_files = [f"validation_{i}.pred" for i in range(4)]
    final_pred_file = "validation_avg.pred"

    for i in range(4):
        mat_file = mat_files[i]
        pred_file = pred_files[i]
    
        # Run evaluation
        if not Path(pred_file).exists():
            with open(pred_file, "w") as fout:
                subprocess.run(
                    [
                        "python", f"{RDIR}/pep2score.py",
                        "-mat", mat_file,
                        "-f", eval_file
                    ],
                    stdout=fout,
                    stderr=subprocess.DEVNULL,
                    env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
                )
    
    # Step 2: Average predictions
    # Assumes each pred_file has one score per line
    all_preds = []
    all_peptide_names = []
    all_real_values = []
    
    # Read all prediction files and collect data
    for idx, pred_file in enumerate(pred_files):
        with open(pred_file) as f:
            preds = []
            peptide_names = []
            real_values = []
            if idx == 0:
                # On first file, also store peptide names and real values
                for line in f:
                    if line.strip() and not line.strip().startswith('#'):
                        parts = line.strip().split()
                        peptide_names.append(parts[0])
                        real_values.append(float(parts[2]))
                        preds.append(float(parts[1]))     
            else:
                for line in f:
                    if line.strip() and not line.strip().startswith('#'):
                        parts = line.strip().split()
                        preds.append(float(parts[1]))  # Or which column is prediction?
    
            all_preds.append(preds)
            
    all_peptide_names.append(peptide_names)
    all_real_values.append(real_values)
    
    # Convert to numpy array for row-wise mean
    all_preds = np.array(all_preds)  # shape: (4, N)
    mean_preds = np.mean(all_preds, axis=0)
    
    # Save final averaged predictions
    with open(final_pred_file, "w") as f:
        for name, pred, real in zip(peptide_names, mean_preds, real_values):
            f.write(f"{name}\t{pred:.6f}\t{real:.6f}\n")
    
    print(f"Saved averaged predictions to {final_pred_file}")

    os.chdir("..")  # up from allele.res
# Out:
# B5801 lambda 0.02 epsilon 0.01 PCC 0.68702 MSE 0.01938
# B5801 lambda 0.02 epsilon 0.04 PCC 0.67719 MSE 0.02012
# B5801 lambda 0.02 epsilon 0.08 PCC 0.66210 MSE 0.02320
# B5801 lambda 0.08 epsilon 0.01 PCC 0.68705 MSE 0.01937
# B5801 lambda 0.08 epsilon 0.04 PCC 0.67719 MSE 0.02012
# B5801 lambda 0.08 epsilon 0.08 PCC 0.66212 MSE 0.02320
# B5801 lambda 0.1 epsilon 0.01 PCC 0.68704 MSE 0.01937
# B5801 lambda 0.1 epsilon 0.04 PCC 0.67724 MSE 0.02011
# B5801 lambda 0.1 epsilon 0.08 PCC 0.66212 MSE 0.02319
#
# Best model for allele B5801 :  lambda 0.08 epsilon 0.01 with correlation 0.68705
#
# Saved averaged predictions to validation_avg.pred

# %% [markdown]
# LOOP FOR NESTED

# %%
# --- Pearson correlation calculator ---
def pearson_from_pairs(pairs):
    n = len(pairs)
    if n == 0:
        return 0.0, float("inf")
    
    x = [p[0] for p in pairs]
    y = [p[1] for p in pairs]
    
    x0 = sum(x) / n
    y0 = sum(y) / n
    
    t = nx = ny = err = 0.0
    for i in range(n):
        dx = x[i] - x0
        dy = y[i] - y0
        t += dx * dy
        nx += dx * dx
        ny += dy * dy
        err += (x[i] - y[i]) ** 2
    
    if nx * ny == 0:
        pcc = 0.0
    else:
        pcc = t / math.sqrt(nx * ny)
    
    mse = err / n
    return pcc, mse

def make_and_enter(dir_path):
    path = Path(dir_path)
    path.mkdir(exist_ok=True)
    os.chdir(path)

def concat_train_files(n_list, allele, DDIR, held_out_fold):
    output_file = Path(f"conc_f00{held_out_fold}")
    if output_file.exists():
        return output_file  # Return existing file without rewriting
    
    with open(output_file, "w") as outfile:
        for n in n_list:
            file_path = Path(f"{DDIR}/{allele}/c00{n}")
            with open(file_path) as infile:
                outfile.writelines(infile.readlines())

def run_training_and_evaluation(RDIR, train_file, eval_file, mat_file, pred_file, _lambda, _epsilon):
    # Run training
    if not Path(mat_file).exists():
        with open(mat_file, "w") as fout:
            subprocess.run(
                [
                    "python", f"{RDIR}/smm_gradient_descent.py",
                    "-l", str(_lambda),
                    "-epi", str(_epsilon),
                    "-t", train_file
                ],
                stdout=fout,
                stderr=subprocess.DEVNULL,
                env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
            )

    # Run evaluation
    if not Path(pred_file).exists():
        with open(pred_file, "w") as fout:
            subprocess.run(
                [
                    "python", f"{RDIR}/pep2score.py",
                    "-mat", mat_file,
                    "-f", eval_file
                ],
                stdout=fout,
                stderr=subprocess.DEVNULL,
                env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
            )

def collect_outer_preds(allele):
    preds = []
    preds_for_file = []
    for path in Path('.').rglob('*.outer_pred'):
        with open(path) as pf:
            for line in pf:
                if "#" not in line and line.strip():
                    try:
                        parts = line.strip().split()
                        preds_for_file.append(f"{parts[0]} {parts[1]} {parts[2]}\n")
                    except:
                        continue

    # Save all collected predictions to a single file
    output_file = Path(f"{allele}_prediction")
    with open(output_file, "w") as out:
        out.writelines(preds_for_file)
    
    print(f"Saved {len(preds_for_file)} predictions to {output_file}")

# %%
os.chdir(RDIR)
# --- Loop over all alleles ---
for allele in alleles:
    make_and_enter(f"{allele}_nested.res")

    # --- Outer Validation loop ---
    for n in folds:
        inner_loop_files = [0, 1, 2, 3]
        inner_loop_files.remove(n)
    
        make_and_enter(f"validation_set_{n}")

        # copy the validation files and create the new concatenated training files
        for m in inner_loop_files:
            # Copy the evaluation file
            eval_file = f"{DDIR}/{allele}/c00{m}"
            shutil.copy(eval_file, f"c00{m}")
            # Create the concatenated trining files
            train_files = inner_loop_files.copy()
            train_files.remove(m)

            concat_train_files(train_files, allele, DDIR, m)
        
        best_pcc = -1000
        best_model = ""
        best_lambda = ""
        best_epsilon = ""
        
    # --- Hyperparameters loop ---    
        for l in lambdas:
            make_and_enter(f"l.{l}")
                
            for epi in epis:
                make_and_enter(f"epi.{epi}")
    
                preds = []

                # --- Inner CV loop ---
                for m in inner_loop_files:
                    
                    # Define the files to start running
                    mat_file = f"mat.{m}"
                    pred_file = f"c00{m}.pred"
                    
                    #eval_file = f"../../c00{m}"
                    eval_file = f"{RDIR}{allele}_nested.res/validation_set_{n}/c00{m}"
                    #train_file = f"../../conc_f00{m}"
                    train_file = f"{RDIR}{allele}_nested.res/validation_set_{n}/conc_f00{m}"
                    
                    # Run training and evalutation
                    
                    run_training_and_evaluation(RDIR, train_file, eval_file, mat_file=mat_file, pred_file=pred_file, _lambda=l, _epsilon=epi)
                    
                    with open(pred_file) as pf:
                        for line in pf:
                            if "#" not in line and line.strip():
                                try:
                                    parts = line.strip().split()
                                    preds.append((float(parts[1]), float(parts[2])))
                                except:
                                    continue
                
                # Compute PCC and MSE
                pcc, mse = pearson_from_pairs(preds)
                eval_output = f"{allele}; Outer validation set = {n}, lambda = {l} epsilon = {epi} PCC {pcc:.5f} MSE {mse:.5f}"
                print(eval_output)

                if pcc > best_pcc:
                    best_pcc = pcc
                    best_lambda = l
                    best_epsilon = epi
                    best_model = f"lambda {best_lambda} epsilon {best_epsilon}"
                    
                
                # Leave epi.{epi}
                os.chdir("..")
        
            # Leave l.{l}
            os.chdir("..")

        # Final result
        print("\nBest model for allele", allele,"and Outer validation set '", n, "', :", best_model, "with correlation", f"{best_pcc:.5f}\n")

        # Copy the final evaluation file
        final_eval_file = f"{DDIR}/{allele}/c00{n}"
        shutil.copy(final_eval_file, f"final_evaluation_c00{n}")
        
        # Copy the full training file to use when the best HP are chosen
        full_train_file = f"{DDIR}/{allele}/f00{n}"
        shutil.copy(full_train_file, f"final_training_f00{n}")

        # Define the files to start running
        mat_file = f"mat.{n}"
        pred_file = f"c00{n}.outer_pred"
                    
        eval_file = f"final_evaluation_c00{n}"
        train_file = f"final_training_f00{n}"

        # Run training and evaluation
        run_training_and_evaluation(RDIR, train_file, eval_file, mat_file=mat_file, pred_file=pred_file, _lambda=best_lambda, _epsilon=best_epsilon)
        
        # Leave validation_set_{n}
        os.chdir("..")

    # Concatenate predictions for allele and get the final measure
    #collect_outer_preds(allele)

    #pairs = []
    #with open(f"{allele}_prediction") as f:
    #    for line in f:
    #        parts = line.strip().split()
    #        try:
    #            x = float(parts[1])  # second column
    #            y = float(parts[2])  # third column
    #            pairs.append((x, y))
    #        except (IndexError, ValueError):
    #            continue
                
    #pcc, mse = pearson_from_pairs(pairs)
    #eval_output = f"Final prediciton for allele:{allele}; PCC {pcc:.5f} MSE {mse:.5f}"
    #print(eval_output)
    eval_file = f"{DDIR}/{allele}/c004"
    mat_files = [f"{RDIR}/{allele}_nested.res/validation_set_{i}/mat.{i}" for i in range(4)]
    pred_files = [f"validation_{i}.pred" for i in range(4)]
    final_pred_file = "validation_avg.pred"

    for i in range(4):
        mat_file = mat_files[i]
        pred_file = pred_files[i]
    
        # Run evaluation
        if not Path(pred_file).exists():
            with open(pred_file, "w") as fout:
                subprocess.run(
                    [
                        "python", f"{RDIR}/pep2score.py",
                        "-mat", mat_file,
                        "-f", eval_file
                    ],
                    stdout=fout,
                    stderr=subprocess.DEVNULL,
                    env={**os.environ, "QT_QPA_PLATFORM": "offscreen"}
                )
    
    # Step 2: Average predictions
    # Assumes each pred_file has one score per line
    all_preds = []
    
    # Read all prediction files and collect data
    for idx, pred_file in enumerate(pred_files):
        with open(pred_file) as f:
            preds = []
            peptide_names = []
            real_values = []
            if idx == 0:
                # On first file, also store peptide names and real values
                for line in f:
                    if line.strip() and not line.strip().startswith('#'):
                        parts = line.strip().split()
                        peptide_names.append(parts[0])
                        real_values.append(float(parts[2]))
                        preds.append(float(parts[1]))     
            else:
                for line in f:
                    if line.strip() and not line.strip().startswith('#'):
                        parts = line.strip().split()
                        preds.append(float(parts[1])) 
    
            all_preds.append(preds)

    
    # Convert to numpy array for row-wise mean
    all_preds = np.array(all_preds)  # shape: (4, N)
    mean_preds = np.mean(all_preds, axis=0)
    
    # Save final averaged predictions
    with open(final_pred_file, "w") as f:
        for name, pred, real in zip(peptide_names, mean_preds, real_values):
            print(name, pred, real)
            f.write(f"{name}\t{pred:.6f}\t{real:.6f}\n")
    
    print(f"Saved averaged predictions to {final_pred_file}")

    # Leave {allele}.res
    os.chdir("..")
# Out:
# B5801; Outer validation set = 0, lambda = 0.02 epsilon = 0.01 PCC 0.63031 MSE 0.02553
# B5801; Outer validation set = 0, lambda = 0.02 epsilon = 0.04 PCC 0.60673 MSE 0.02789
# B5801; Outer validation set = 0, lambda = 0.02 epsilon = 0.08 PCC 0.57982 MSE 0.03046
# B5801; Outer validation set = 0, lambda = 0.08 epsilon = 0.01 PCC 0.63041 MSE 0.02551
# B5801; Outer validation set = 0, lambda = 0.08 epsilon = 0.04 PCC 0.60685 MSE 0.02786
# B5801; Outer validation set = 0, lambda = 0.08 epsilon = 0.08 PCC 0.57988 MSE 0.03044
# B5801; Outer validation set = 0, lambda = 0.1 epsilon = 0.01 PCC 0.63043 MSE 0.02551
# B5801; Outer validation set = 0, lambda = 0.1 epsilon = 0.04 PCC 0.60692 MSE 0.02785
# B5801; Outer validation set = 0, lambda = 0.1 epsilon = 0.08 PCC 0.57991 MSE 0.03043
#
# Best model for allele B5801 and Outer validation set ' 0 ', : lambda 0.1 epsilon 0.01 with correlation 0.63043
#
# B5801; Outer validation set = 1, lambda = 0.02 epsilon = 0.01 PCC 0.64165 MSE 0.02384
# B5801; Outer validation set = 1, lambda = 0.02 epsilon = 0.04 PCC 0.60577 MSE 0.02700
# B5801; Outer validation set = 1, lambda = 0.02 epsilon = 0.08 PCC 0.57534 MSE 0.03015
# B5801; Outer validation set = 1, lambda = 0.08 epsilon = 0.01 PCC 0.64173 MSE 0.02382
# B5801; Outer validation set = 1, lambda = 0.08 epsilon = 0.04 PCC 0.60586 MSE 0.02698
# B5801; Outer validation set = 1, lambda = 0.08 epsilon = 0.08 PCC 0.57539 MSE 0.03013
# B5801; Outer validation set = 1, lambda = 0.1 epsilon = 0.01 PCC 0.64172 MSE 0.02382
# B5801; Outer validation set = 1, lambda = 0.1 epsilon = 0.04 PCC 0.60588 MSE 0.02697
# B5801; Outer validation set = 1, lambda = 0.1 epsilon = 0.08 PCC 0.57542 MSE 0.03012
#
# Best model for allele B5801 and Outer validation set ' 1 ', : lambda 0.08 epsilon 0.01 with correlation 0.64173
#
# B5801; Outer validation set = 2, lambda = 0.02 epsilon = 0.01 PCC 0.64082 MSE 0.02397
# B5801; Outer validation set = 2, lambda = 0.02 epsilon = 0.04 PCC 0.60650 MSE 0.02663
# B5801; Outer validation set = 2, lambda = 0.02 epsilon = 0.08 PCC 0.57855 MSE 0.02923
# B5801; Outer validation set = 2, lambda = 0.08 epsilon = 0.01 PCC 0.64087 MSE 0.02396
# B5801; Outer validation set = 2, lambda = 0.08 epsilon = 0.04 PCC 0.60660 MSE 0.02660
# B5801; Outer validation set = 2, lambda = 0.08 epsilon = 0.08 PCC 0.57856 MSE 0.02921
# B5801; Outer validation set = 2, lambda = 0.1 epsilon = 0.01 PCC 0.64092 MSE 0.02395
# B5801; Outer validation set = 2, lambda = 0.1 epsilon = 0.04 PCC 0.60661 MSE 0.02660
# B5801; Outer validation set = 2, lambda = 0.1 epsilon = 0.08 PCC 0.57860 MSE 0.02920
#
# Best model for allele B5801 and Outer validation set ' 2 ', : lambda 0.1 epsilon 0.01 with correlation 0.64092
#
# B5801; Outer validation set = 3, lambda = 0.02 epsilon = 0.01 PCC 0.61519 MSE 0.02714
# B5801; Outer validation set = 3, lambda = 0.02 epsilon = 0.04 PCC 0.57841 MSE 0.03089
# B5801; Outer validation set = 3, lambda = 0.02 epsilon = 0.08 PCC 0.55037 MSE 0.03409
# B5801; Outer validation set = 3, lambda = 0.08 epsilon = 0.01 PCC 0.61526 MSE 0.02713
# B5801; Outer validation set = 3, lambda = 0.08 epsilon = 0.04 PCC 0.57849 MSE 0.03086
# B5801; Outer validation set = 3, lambda = 0.08 epsilon = 0.08 PCC 0.55047 MSE 0.03407
# B5801; Outer validation set = 3, lambda = 0.1 epsilon = 0.01 PCC 0.61530 MSE 0.02712
# B5801; Outer validation set = 3, lambda = 0.1 epsilon = 0.04 PCC 0.57854 MSE 0.03086
# B5801; Outer validation set = 3, lambda = 0.1 epsilon = 0.08 PCC 0.55050 MSE 0.03405
#
# Best model for allele B5801 and Outer validation set ' 3 ', : lambda 0.1 epsilon 0.01 with correlation 0.61530
#
# ['YSAVVPLVY', '0.5257999999999999', '1.0']
# ['YTAVVKLVY', '0.412', '0.878323']
# ['YTAVVPLVI', '0.4673', '0.858937']
# ['KSLGIDQIW', '0.6717', '0.80452']
# ['EEFLQCGRL', '-0.0408', '0.084687']
# ['DYPDDFMDK', '-0.1136', '0.084687']
# ['DTVNRTHQY', '0.1195', '0.084687']
# ['DSDGSFFLY', '0.17939999999999998', '0.084687']
# ['DPRDDLSGM', '-0.013099999999999997', '0.084687']
# ['DLNKVIQFL', '0.07339999999999999', '0.084687']
# ['DFPIFNQRY', '-0.0182', '0.084687']
# ['CYPRLWGVR', '-0.031900000000000005', '0.084687']
# ['CHKGWGVSV', '-0.021099999999999997', '0.084687']
# ['AYLLQHLDL', '0.1192', '0.084687']
# ['AVDPAKAYK', '-0.0384', '0.084687']
# ['ATNNVFRLK', '0.0732', '0.084687']
# ['ATFSRPGSL', '0.15030000000000002', '0.084687']
# ['ASDRISGIL', '0.11649999999999998', '0.084687']
# ['ARADGILRF', '0.1125', '0.084687']
# ['APRTVALTA', '0.05510000000000001', '0.084687']
# ['APIEHIASM', '0.12029999999999999', '0.084687']
# ['ALYWALMES', '0.11459999999999998', '0.084687']
# ['ALPPPPPPP', '0.06389999999999998', '0.084687']
# ['ALIVAIWDK', '0.10449999999999997', '0.084687']
# ['ALASFLFGF', '0.18270000000000003', '0.084687']
# ['AIKCVDIVK', '-0.0362', '0.084687']
# ['AFDIASVFF', '0.030899999999999997', '0.084687']
# ['AEMGGHAER', '0.0758', '0.084687']
# ['AEFPVGSTA', '0.0924', '0.084687']
# ['ACMDGFEVV', '0.0506', '0.084687']
# ['IQQLPETYF', '0.1279', '0.070255']
# ['YVFPVIFSK', '0.12729999999999997', '0.0']
# Saved averaged predictions to validation_avg.pred
# A0201; Outer validation set = 0, lambda = 0.02 epsilon = 0.01 PCC 0.78428 MSE 0.03690
# A0201; Outer validation set = 0, lambda = 0.02 epsilon = 0.04 PCC 0.76639 MSE 0.04043
# A0201; Outer validation set = 0, lambda = 0.02 epsilon = 0.08 PCC 0.72633 MSE 0.04914
# A0201; Outer validation set = 0, lambda = 0.08 epsilon = 0.01 PCC 0.78429 MSE 0.03690
# A0201; Outer validation set = 0, lambda = 0.08 epsilon = 0.04 PCC 0.75800 MSE 0.04196
# A0201; Outer validation set = 0, lambda = 0.08 epsilon = 0.08 PCC 0.72634 MSE 0.04914
# A0201; Outer validation set = 0, lambda = 0.1 epsilon = 0.01 PCC 0.78428 MSE 0.03690
# A0201; Outer validation set = 0, lambda = 0.1 epsilon = 0.04 PCC 0.75800 MSE 0.04196
# A0201; Outer validation set = 0, lambda = 0.1 epsilon = 0.08 PCC 0.72633 MSE 0.04914
#
# Best model for allele A0201 and Outer validation set ' 0 ', : lambda 0.08 epsilon 0.01 with correlation 0.78429
#
# A0201; Outer validation set = 1, lambda = 0.02 epsilon = 0.01 PCC 0.77777 MSE 0.03810
# A0201; Outer validation set = 1, lambda = 0.02 epsilon = 0.04 PCC 0.75477 MSE 0.04296
# A0201; Outer validation set = 1, lambda = 0.02 epsilon = 0.08 PCC 0.72313 MSE 0.05066
# A0201; Outer validation set = 1, lambda = 0.08 epsilon = 0.01 PCC 0.77777 MSE 0.03810
# A0201; Outer validation set = 1, lambda = 0.08 epsilon = 0.04 PCC 0.75477 MSE 0.04295
# A0201; Outer validation set = 1, lambda = 0.08 epsilon = 0.08 PCC 0.72314 MSE 0.05065
# A0201; Outer validation set = 1, lambda = 0.1 epsilon = 0.01 PCC 0.77778 MSE 0.03810
# A0201; Outer validation set = 1, lambda = 0.1 epsilon = 0.04 PCC 0.75477 MSE 0.04295
# A0201; Outer validation set = 1, lambda = 0.1 epsilon = 0.08 PCC 0.72314 MSE 0.05065
#
# Best model for allele A0201 and Outer validation set ' 1 ', : lambda 0.1 epsilon 0.01 with correlation 0.77778
#
# A0201; Outer validation set = 2, lambda = 0.02 epsilon = 0.01 PCC 0.78178 MSE 0.03713
# A0201; Outer validation set = 2, lambda = 0.02 epsilon = 0.04 PCC 0.75551 MSE 0.04218
# A0201; Outer validation set = 2, lambda = 0.02 epsilon = 0.08 PCC 0.72130 MSE 0.04965
# A0201; Outer validation set = 2, lambda = 0.08 epsilon = 0.01 PCC 0.78178 MSE 0.03713
# A0201; Outer validation set = 2, lambda = 0.08 epsilon = 0.04 PCC 0.75551 MSE 0.04217
# A0201; Outer validation set = 2, lambda = 0.08 epsilon = 0.08 PCC 0.72131 MSE 0.04964
# A0201; Outer validation set = 2, lambda = 0.1 epsilon = 0.01 PCC 0.78178 MSE 0.03713
# A0201; Outer validation set = 2, lambda = 0.1 epsilon = 0.04 PCC 0.75551 MSE 0.04217
# A0201; Outer validation set = 2, lambda = 0.1 epsilon = 0.08 PCC 0.72130 MSE 0.04964
#
# Best model for allele A0201 and Outer validation set ' 2 ', : lambda 0.02 epsilon 0.01 with correlation 0.78178
#
# A0201; Outer validation set = 3, lambda = 0.02 epsilon = 0.01 PCC 0.78734 MSE 0.03656
# A0201; Outer validation set = 3, lambda = 0.02 epsilon = 0.04 PCC 0.77471 MSE 0.03982
# A0201; Outer validation set = 3, lambda = 0.02 epsilon = 0.08 PCC 0.74780 MSE 0.04618
# A0201; Outer validation set = 3, lambda = 0.08 epsilon = 0.01 PCC 0.78734 MSE 0.03656
# A0201; Outer validation set = 3, lambda = 0.08 epsilon = 0.04 PCC 0.77469 MSE 0.03982
# A0201; Outer validation set = 3, lambda = 0.08 epsilon = 0.08 PCC 0.74780 MSE 0.04617
# A0201; Outer validation set = 3, lambda = 0.1 epsilon = 0.01 PCC 0.78734 MSE 0.03656
# A0201; Outer validation set = 3, lambda = 0.1 epsilon = 0.04 PCC 0.77470 MSE 0.03982
# A0201; Outer validation set = 3, lambda = 0.1 epsilon = 0.08 PCC 0.74781 MSE 0.04617
#
# Best model for allele A0201 and Outer validation set ' 3 ', : lambda 0.08 epsilon 0.01 with correlation 0.78734
#
# ['YMMGIEYGL', '0.8978999999999999', '1.0']
# ['YLMPYSVYI', '1.0006', '1.0']
# ['YLDFLLLLL', '0.7612000000000001', '1.0']
# ['WLYGYNFII', '0.8428000000000001', '1.0']
# ['VLDTTLYAV', '0.7288999999999999', '1.0']
# ['TLIDIWFLA', '0.7135', '1.0']
# ['SLLYLILFL', '0.7767', '1.0']
# ['RTFHIFYYL', '0.6022000000000001', '1.0']
# ['RLAVYIDKV', '0.7116', '1.0']
# ['NLLLWPLYV', '0.7378', '1.0']
# ['MLMEVFPQL', '0.9174000000000002', '1.0']
# ['LMIFISSFL', '0.687', '1.0']
# ['LLNLLLWPL', '0.681', '1.0']
# ['KVYDKLFPV', '0.7708', '1.0']
# ['KLFYVYYNL', '0.7890999999999999', '1.0']
# ['ILPVIFLSI', '0.5980000000000001', '1.0']
# ['GLLRVISGV', '0.6936', '1.0']
# ['FVFAWFNGV', '0.7184999999999999', '1.0']
# ['FLSRVFFCV', '0.9190000000000002', '1.0']
# ['FLSHDFTLV', '0.8838', '1.0']
# ['FLIDLAFLI', '0.885', '1.0']
# ['FLDNECHTI', '0.7077', '1.0']
# ['FILGIIITV', '0.8859999999999999', '1.0']
# ['FAAELTIGV', '0.6456999999999999', '1.0']
# ['FVFDRPLPV', '0.6708', '0.998232']
# ['SVVIYDFLV', '0.5394', '0.994231']
# ['YMNYYTTYI', '0.919', '0.990167']
# ['KMIYDLNAV', '0.7711', '0.981344']
# ['FMYIESIKV', '0.8015999999999999', '0.976087']
# ['GLNDYLHSV', '0.8744', '0.974867']
# ['KLFTHDIML', '0.6083000000000001', '0.969224']
# ['FTSDYPFYV', '0.867', '0.962279']
# ['ILDDNLYKV', '0.7954', '0.957636']
# ['SVMNFIPII', '0.5802', '0.950502']
# ['ILSCIFAFI', '0.7736000000000001', '0.944978']
# ['YLVSFGVWI', '0.7476', '0.940678']
# ['YLMKDKLNI', '0.7066', '0.93634']
# ['KLFTDNNFL', '0.7411000000000001', '0.935209']
# ['NMISDTIFV', '0.7874', '0.928852']
# ['LLGTFTWTL', '0.7136', '0.924122']
# ['VLLGVVFGV', '0.8625', '0.919086']
# ['FLRYLLFGI', '0.7642000000000001', '0.915924']
# ['SLVSKHWEL', '0.5664', '0.907374']
# ['KMIPLLFIL', '0.7829000000000002', '0.902394']
# ['FLKDVMVEI', '0.6711', '0.898122']
# ['YLWPGPVTA', '0.6762', '0.891723']
# ['RLRSSVPGV', '0.5650000000000001', '0.890001']
# ['FLYGAALLA', '0.6536', '0.886895']
# ['FLHYCNSYA', '0.6882', '0.882288']
# ['NMVPFFPPV', '0.7414000000000001', '0.873044']
# ['YLAKLTALV', '0.8099000000000001', '0.869615']
# ['ALAPSTMKI', '0.5833000000000002', '0.864388']
# ['QLLQANPIL', '0.5397000000000001', '0.860333']
# ['ILYQVPFSV', '0.8436', '0.852848']
# ['NLFDIPLLT', '0.5285', '0.850272']
# ['KVLSIMAFI', '0.5208', '0.845524']
# ['YLDLALMSV', '0.8270000000000001', '0.840776']
# ['HIFYQLANV', '0.5347', '0.837319']
# ['FIISTLNKI', '0.5187999999999999', '0.832497']
# ['KLVSISNFI', '0.653', '0.829608']
# ['KLYIALCKV', '0.6874', '0.82464']
# ['ILMYPTTLL', '0.7457', '0.820517']
# ['LLLDYMTST', '0.6680000000000001', '0.819651']
# ['YTQDELINV', '0.6054999999999999', '0.816422']
# ['ILMQVPFSV', '0.8962', '0.814044']
# ['SIMETIDPV', '0.7239', '0.809459']
# ['MIYGLIACL', '0.7020000000000002', '0.80245']
# ['GLLGWSPQA', '0.6782', '0.800236']
# ['TIWAANAGV', '0.506', '0.79853']
# ['LLTYFCFVA', '0.6285999999999999', '0.795821']
# ['YLVAYKATV', '0.7644', '0.7943']
# ['YLKAYQATV', '0.7069000000000001', '0.792573']
# ['SLSLHPLYV', '0.6494', '0.78892']
# ['GQWDGWVWL', '0.5096', '0.783474']
# ['KTWGQYWQV', '0.5288999999999999', '0.7781']
# ['LLSLFSTLV', '0.7423000000000001', '0.773373']
# ['VIHDYICWL', '0.6394', '0.771343']
# ['MIGNYFSGV', '0.6718999999999999', '0.770145']
# ['NMQTVKLFV', '0.5085999999999999', '0.766571']
# ['LIVRYLIQV', '0.6399999999999999', '0.765396']
# ['SQYYFSMLV', '0.683', '0.763617']
# ['YLLAVCGCI', '0.6971', '0.760773']
# ['LMTLYQIQV', '0.6579999999999999', '0.75609']
# ['FIDILLFVI', '0.6474', '0.753265']
# ['GLLDSIKMI', '0.5710999999999999', '0.750105']
# ['YLAPGPVTV', '0.7818', '0.748692']
# ['HLTENNLYI', '0.5965', '0.74698']
# ['LLAQFTSAI', '0.6246', '0.743938']
# ['VLSEYETMV', '0.7422000000000001', '0.740499']
# ['YLKIGTLLV', '0.6801', '0.739479']
# ['LLIHFLLSL', '0.7513000000000001', '0.737613']
# ['FLICHNLRA', '0.7202', '0.735869']
# ['YLVAYQATV', '0.8406', '0.732907']
# ['KLLNMRDLI', '0.4888000000000001', '0.730555']
# ['FVAVHPVDV', '0.3939', '0.727865']
# ['GLFIYIPGT', '0.6469', '0.725513']
# ['SLSHNFTLV', '0.6963', '0.723836']
# ['GLIEEMASA', '0.615', '0.723124']
# ['YLVAYQAKV', '0.7867999999999999', '0.719352']
# ['GLHCDFACL', '0.5861000000000001', '0.714886']
# ['QLVWENFLA', '0.6224', '0.713047']
# ['YLSPGPVTV', '0.7879', '0.711217']
# ['SLLPAIVEL', '0.6709', '0.706274']
# ['RVIEVLQRA', '0.39630000000000004', '0.702501']
# ['WLGAAITLV', '0.6669', '0.700536']
# ['LLLCLIFLL', '0.8658000000000001', '0.698876']
# ['IMMGVLVGV', '0.8492999999999999', '0.695388']
# ['YIWIKNLET', '0.4442', '0.69251']
# ['NLAADLTQI', '0.5939', '0.692142']
# ['ILISLINSL', '0.6691', '0.68968']
# ['YLVAKQATV', '0.7056', '0.68748']
# ['FVDGVPFVV', '0.6197999999999999', '0.683289']
# ['KLFFAKCLV', '0.6042000000000001', '0.681872']
# ['KMFCQLAKV', '0.6804', '0.676841']
# ['RILQQLLFI', '0.5045999999999999', '0.676482']
# ['RLLGTFTWT', '0.5377000000000001', '0.674672']
# ['ALWEIQQVV', '0.6749', '0.671705']
# ['ATVGIMIGV', '0.5203', '0.669573']
# ['YIIRVTTEL', '0.6375', '0.668097']
# ['ITATFTAPL', '0.48050000000000004', '0.663802']
# ['YLLEKSRAI', '0.6204000000000001', '0.660792']
# ['ITMQVPFSV', '0.6498999999999999', '0.659061']
# ['LLMGTLGIV', '0.7024000000000001', '0.657216']
# ['YMLDLQPET', '0.6236999999999999', '0.654939']
# ['SLYNTVATL', '0.5921000000000001', '0.653181']
# ['LLGRNSFEV', '0.6471', '0.651288']
# ['LLWDYMCIS', '0.5503', '0.647576']
# ['ILAADLEKL', '0.5948', '0.645551']
# ['KLLYAAEMV', '0.6320000000000001', '0.643104']
# ['MAWGGSYIA', '0.4675', '0.640268']
# ['IILLILSCI', '0.5247999999999999', '0.63832']
# ['LAALFMYYA', '0.4439', '0.634224']
# ['HLINKLLST', '0.44399999999999995', '0.630358']
# ['TLFLLFLEI', '0.5873', '0.627799']
# ['RLIDFLKDV', '0.6496000000000001', '0.62472']
# ['GLVDLFVFS', '0.5106999999999999', '0.621337']
# ['FTDQVPFSV', '0.6508', '0.619412']
# ['GLSRYVARL', '0.6027', '0.617022']
# ['FKNSSNLFT', '0.3628', '0.615622']
# ['KVAEIVHFL', '0.5974999999999999', '0.612778']
# ['ALMTLDDLA', '0.5196', '0.610834']
# ['FANHAFTLV', '0.5481', '0.609128']
# ['YVHGDTYSL', '0.5592999999999999', '0.605917']
# ['GLIIISIFL', '0.7623', '0.604242']
# ['VLLDYQGML', '0.6148', '0.603373']
# ['SLYNTVATI', '0.5935000000000001', '0.601816']
# ['TLNFPISPI', '0.514', '0.600105']
# ['KVAELVHFL', '0.5444', '0.599637']
# ['LMWITQCFL', '0.5586', '0.597338']
# ['YQDPQNYEL', '0.5637', '0.596161']
# ['KVCAITPTI', '0.39770000000000005', '0.594557']
# ['VLTALLAGL', '0.5229000000000001', '0.592716']
# ['SVMDPLIYA', '0.5415', '0.591429']
# ['MIFVSSIFI', '0.6777000000000001', '0.589395']
# ['YLEPGPVTL', '0.5582', '0.586716']
# ['AIYGRPVSA', '0.4153', '0.585145']
# ['LQQSTYQLV', '0.3782', '0.582749']
# ['YLVAYQKTV', '0.7172000000000001', '0.581488']
# ['ALDVYNGLL', '0.5868000000000002', '0.578148']
# ['LMDCIIFES', '0.6492', '0.575592']
# ['ALCRWGLLL', '0.4671', '0.574375']
# ['TLGIVCPIC', '0.09470000000000003', '0.573437']
# ['ALEAKIAQL', '0.4628000000000001', '0.571579']
# ['YVITTQHWL', '0.5538000000000001', '0.570661']
# ['KIFEYGFTF', '0.558', '0.569426']
# ['YIPPCQCTV', '0.5941000000000001', '0.56792']
# ['IITILQDIV', '0.3634', '0.566497']
# ['ILYAAFLWL', '0.7453000000000001', '0.56399']
# ['ILAGYGAGV', '0.7179', '0.560669']
# ['KINIFMAFL', '0.5843', '0.559']
# ['FANHNFTLV', '0.5422', '0.558159']
# ['DLERKVESL', '0.17480000000000004', '0.55648']
# ['VLSDFKSWL', '0.6326', '0.555845']
# ['GLRQQLEDI', '0.2805', '0.553789']
# ['ILRKIFYSV', '0.7058', '0.553247']
# ['ALPHAILRL', '0.5441', '0.5518']
# ['MIIGEPIIV', '0.6904', '0.550014']
# ['YVPGYSITT', '0.43110000000000004', '0.548864']
# ['TLIQYRQQL', '0.5213', '0.54718']
# ['TMSIYIAVA', '0.5292', '0.545922']
# ['RFLEDYFGV', '0.6103000000000001', '0.542619']
# ['TLVPQEHYV', '0.5493', '0.539731']
# ['QLIPCMDVV', '0.6109', '0.538768']
# ['MAFDISVNA', '0.5263', '0.537659']
# ['KMAVEVGSI', '0.5095000000000001', '0.533767']
# ['KIYKIIIWI', '0.7655', '0.532685']
# ['CLLQSLQQI', '0.496', '0.531515']
# ['MMVILPDKI', '0.49800000000000005', '0.530313']
# ['CLTSTVQLV', '0.4773', '0.528032']
# ['VLIALSVLA', '0.589', '0.527162']
# ['ILFIMFMLI', '0.7066000000000001', '0.525679']
# ['FIYLLFASM', '0.5166', '0.523793']
# ['KLQWLFAAL', '0.5807', '0.521342']
# ['SLEATFIDV', '0.47630000000000006', '0.518994']
# ['HLAGFIHAC', '0.3524999999999999', '0.517044']
# ['AMLQLDPNA', '0.42319999999999997', '0.513937']
# ['MVDVSMMSM', '0.3691', '0.51046']
# ['ILSLETVKM', '0.4332000000000001', '0.508429']
# ['LLWFHISCL', '0.6718999999999999', '0.506687']
# ['LLLEVEQEI', '0.6241000000000001', '0.504491']
# ['YMIMVKCWM', '0.564', '0.502602']
# ['YIFRNTINM', '0.49990000000000007', '0.500542']
# ['MVTDKTAYI', '0.5059000000000001', '0.498531']
# ['LVGPTPVNI', '0.21760000000000002', '0.497807']
# ['VLQQNNSFI', '0.5129000000000001', '0.495869']
# ['VLETAVGLL', '0.39220000000000005', '0.494234']
# ['ALIHHNTHL', '0.5409999999999999', '0.494196']
# ['IVVPVIDRL', '0.37470000000000003', '0.492965']
# ['ELMESRMRI', '0.4898', '0.491171']
# ['YNLSLSAAV', '0.3779', '0.488012']
# ['DMYDQQLSV', '0.5019', '0.48539']
# ['MMLAQAYYG', '0.48339999999999994', '0.481554']
# ['VLPPLSADL', '0.3907000000000001', '0.47928']
# ['KMEDSVGCL', '0.489', '0.478047']
# ['ACMDGFEVV', '0.3215', '0.475897']
# ['KLFGFGAQF', '0.4671000000000001', '0.473378']
# ['FVNHRFTLV', '0.5736', '0.471755']
# ['SVDFYQFRV', '0.572', '0.469212']
# ['KMVGTVQRV', '0.6321', '0.467743']
# ['KLYGYASLT', '0.5516000000000001', '0.465219']
# ['MLLAVLYCL', '0.8526', '0.463192']
# ['IILFILFFA', '0.6858', '0.462651']
# ['CTMERTNDL', '0.24710000000000004', '0.459897']
# ['RTNDLTALL', '0.4128', '0.456856']
# ['TLHEYMLDL', '0.514', '0.454354']
# ['LLDCIMFQS', '0.5913000000000002', '0.450679']
# ['SIFLHLVKI', '0.44410000000000005', '0.449874']
# ['AAAKAAAAV', '0.24789999999999998', '0.448061']
# ['KVIKLVKSL', '0.317', '0.447356']
# ['QLEELEDEL', '0.3522', '0.445234']
# ['KLSNAKWLA', '0.5253000000000001', '0.443394']
# ['GLENGLNYI', '0.46840000000000004', '0.440346']
# ['ALQNVMISI', '0.5820000000000001', '0.437397']
# ['SLADTNSLA', '0.5509000000000001', '0.434423']
# ['FFGWEGVGV', '0.3986', '0.432303']
# ['VMPEKRNVV', '0.3721', '0.426483']
# ['RMYGISPWT', '0.6034', '0.42428']
# ['LISLNSMYT', '0.33620000000000005', '0.419891']
# ['GVLIAGIIL', '0.30179999999999996', '0.417693']
# ['ITLVVISVI', '0.33870000000000006', '0.416696']
# ['KVADLVGFL', '0.4696', '0.412756']
# ['SLFNTVATI', '0.5885000000000001', '0.410055']
# ['VQEFIFSAL', '0.2744', '0.406701']
# ['ITSQVPFSV', '0.5459', '0.403238']
# ['LLIDDSFSS', '0.648', '0.401401']
# ['DPKVKQWPL', '-0.08279999999999998', '0.39899']
# ['STLIVTIYV', '0.5660000000000001', '0.397573']
# ['SVPLPCQLM', '0.061399999999999996', '0.392828']
# ['FINFFNLLA', '0.5862999999999998', '0.39121']
# ['MLKLFTHDI', '0.5071000000000001', '0.389875']
# ['KVTGSYNLV', '0.4042', '0.387627']
# ['AMAETGCDA', '0.3229', '0.385329']
# ['DLLNVTYNI', '0.49850000000000005', '0.383746']
# ['YLVIYLNRT', '0.5768000000000001', '0.380044']
# ['LVDLFVFST', '0.39249999999999996', '0.378413']
# ['FVSTMPVET', '0.30219999999999997', '0.377621']
# ['NVDIIDLLL', '0.27649999999999997', '0.375737']
# ['YASLTTIGT', '0.3012', '0.374593']
# ['IAVSVYGAI', '0.21500000000000002', '0.372969']
# ['MLDLQPETT', '0.3754', '0.370452']
# ['LTNAISSRV', '0.4114', '0.369713']
# ['WIKDIMTST', '0.2748', '0.366512']
# ['AVIIMAINV', '0.40419999999999995', '0.36504']
# ['DTMSIYIAV', '0.4043', '0.362792']
# ['FANYNFTLL', '0.5023', '0.358764']
# ['PISDYSAEV', '0.5385', '0.357124']
# ['TLILSNKLL', '0.4159', '0.356005']
# ['VQQESSFVM', '0.30679999999999996', '0.354921']
# ['GVLQTFMRM', '0.26639999999999997', '0.353856']
# ['VTLNRIKIA', '0.16599999999999998', '0.352404']
# ['VIERINLLV', '0.4227', '0.346832']
# ['FTEGKINPL', '0.37240000000000006', '0.346302']
# ['PASISSVLT', '-0.009600000000000004', '0.345013']
# ['ILSPHNVVT', '0.3967', '0.343063']
# ['SLQSAGFTA', '0.4629000000000001', '0.340939']
# ['DIINSVSII', '0.2673', '0.338827']
# ['RALLNMIGM', '0.2363', '0.336198']
# ['NTFVNFNSV', '0.358', '0.335054']
# ['FLADYRGKT', '0.4786000000000001', '0.332838']
# ['YLGPTIRVW', '0.2833', '0.331254']
# ['MNIVLIALS', '0.15399999999999997', '0.329633']
# ['YIALGRARV', '0.486', '0.32801']
# ['RLQMAGVEV', '0.5289', '0.327201']
# ['AAIDRQVSV', '0.4676', '0.325913']
# ['YLDFGGPEG', '0.45630000000000004', '0.324273']
# ['RTMPNESRV', '0.41359999999999997', '0.323734']
# ['ITVLTSVDI', '0.17149999999999999', '0.321794']
# ['LLEQLIENI', '0.47770000000000007', '0.319618']
# ['ELWKDVDRI', '0.4355', '0.317034']
# ['EIIELTRTL', '0.3186', '0.084687']
# ['EHAGVISVL', '0.11510000000000001', '0.084687']
# ['EFFDGGLTF', '0.020000000000000018', '0.084687']
# ['EEMPLVWDL', '0.2733', '0.084687']
# ['EEDLPVTWR', '-0.08260000000000002', '0.084687']
# ['DYDQRDYGF', '-0.1341', '0.084687']
# ['DTVNRTHQY', '-0.07969999999999995', '0.084687']
# ['DSDPMDGCE', '-0.1485', '0.084687']
# ['DPSMLRTTA', '-0.0836', '0.084687']
# ['DLPPAIAAE', '0.22330000000000003', '0.084687']
# ['DFIGKTIGF', '0.004100000000000006', '0.084687']
# ['CYDLMSFLE', '0.1791', '0.084687']
# ['CHKGWGVSV', '0.1503', '0.084687']
# ['AYMDRKSFK', '0.1532', '0.084687']
# ['ATTHSWIPK', '0.058699999999999995', '0.084687']
# ['ASSWAPTQK', '0.09020000000000003', '0.084687']
# ['ASDDLEHWQ', '0.2539', '0.084687']
# ['AQRPAKYSY', '0.024999999999999994', '0.084687']
# ['APRTLVLLL', '0.1787', '0.084687']
# ['ANPGRVKDW', '-0.34630000000000005', '0.084687']
# ['ALASFLFGF', '0.5757000000000001', '0.084687']
# ['AIKCVDIVK', '0.019999999999999997', '0.084687']
# ['AFDWPELEF', '0.03470000000000001', '0.084687']
# ['AEMRETHWL', '0.429', '0.084687']
# ['AEFWDVFLS', '0.34740000000000004', '0.084687']
# ['AAGLPAIFV', '0.2608', '0.084687']
# ['SMYSTVATS', '0.35480000000000006', '0.082685']
# ['AQIDNYNKF', '0.19609999999999994', '0.080766']
# ['SLLMWITQC', '0.4196000000000001', '0.07987']
# ['EVIPMFSAL', '0.2369', '0.074854']
# ['YFDPANGKF', '0.1042', '0.073166']
# ['GTKGKLYIA', '0.1798', '0.070527']
# ['SVFHEHIFK', '0.24419999999999994', '0.067537']
# ['GARVIWMDA', '0.0049999999999999906', '0.065661']
# ['PVVPNAPPA', '0.06849999999999999', '0.064063']
# ['DLFGIWSKV', '0.46270000000000006', '0.064063']
# ['DTDIVNNFI', '0.17670000000000002', '0.05971']
# ['MQLKIDKLT', '0.19299999999999998', '0.058386']
# ['AIKSNNHLT', '0.13820000000000002', '0.056378']
# ['KTEHCDDFM', '0.0945', '0.052182']
# ['RLEVIGLTT', '0.24209999999999998', '0.050889']
# ['TTENAAYQV', '0.1865', '0.048586']
# ['NLDRSNDKV', '0.46670000000000006', '0.047212']
# ['EMRELRRQV', '0.19069999999999998', '0.04566']
# ['RSASGGVYL', '0.3129', '0.03968']
# ['LVQYRILPM', '0.3198', '0.033844']
# ['FPVRPQVPL', '0.2434', '0.032965']
# ['SVAKCCSKT', '0.12409999999999999', '0.028144']
# ['NTHIYLGSA', '0.1818', '0.023543']
# ['DAINKCVDI', '0.034400000000000014', '0.020661']
# ['YCLDFLFDV', '0.5518000000000001', '0.01902']
# ['EIQNVTGFM', '0.13890000000000002', '0.0168']
# ['TMERTNDLT', '0.09599999999999997', '0.014615']
# ['NINFNNSSI', '0.33540000000000003', '0.01068']
# ['IAMLKSKNI', '0.21040000000000006', '0.006249']
# ['KINNNRIVA', '0.25210000000000005', '0.004773']
# ['CAVNTPVSM', '0.02520000000000001', '0.001759']
# ['YSDIPRLKK', '0.022899999999999997', '0.0']
# ['WVKKGGHVT', '-0.126', '0.0']
# ['WIKNLETYT', '0.11910000000000001', '0.0']
# ['VVHFFKNIV', '0.2208', '0.0']
# ['VTGFMEEEI', '0.16970000000000002', '0.0']
# ['VINRVSENT', '0.17729999999999999', '0.0']
# ['TTRAWFDKK', '-0.023700000000000027', '0.0']
# ['TISSESLVY', '0.12610000000000002', '0.0']
# ['SVKERGPAY', '-0.05610000000000001', '0.0']
# ['SPRPEMQEF', '-0.09749999999999999', '0.0']
# ['SIRDGVRAY', '0.0683', '0.0']
# ['RVISDGYFK', '0.26030000000000003', '0.0']
# ['RLKPVGSAY', '0.1408', '0.0']
# ['RAAGLQDCT', '0.0926', '0.0']
# ['QFNFNGHTY', '-0.052', '0.0']
# ['PTPKKMNIV', '0.07659999999999997', '0.0']
# ['PTDMLKLFT', '-0.0466', '0.0']
# ['PADCFLVKL', '0.2439', '0.0']
# ['NTCKPTILA', '0.12229999999999999', '0.0']
# ['NLFSKNILK', '0.38399999999999995', '0.0']
# ['NAVTTNNLL', '0.20550000000000002', '0.0']
# ['MVIENGILK', '0.31359999999999993', '0.0']
# ['LVDKEDTDI', '0.1669', '0.0']
# ['LSAAVKAGA', '0.1711', '0.0']
# ['LLKNMKQCT', '0.12110000000000004', '0.0']
# ['KTFPPTEPK', '0.19920000000000002', '0.0']
# ['KLTKDRKML', '0.2775', '0.0']
# ['IVSHLRAST', '0.09550000000000002', '0.0']
# ['ITNILGGVL', '0.0942', '0.0']
# ['ILTYNKTSK', '0.2366', '0.0']
# ['HPNIEEVAL', '0.11839999999999999', '0.0']
# ['GITRPTTLV', '0.40380000000000005', '0.0']
# ['FTNNKFTLS', '0.23409999999999997', '0.0']
# ['FPREGVFVF', '0.16989999999999994', '0.0']
# ['EVMPVSMAK', '0.1279', '0.0']
# ['ETLNEYKQL', '0.04970000000000001', '0.0']
# ['EMKINRQIL', '0.07249999999999998', '0.0']
# ['ELKDLLNVT', '0.10910000000000004', '0.0']
# ['ELAAHQKKI', '0.21580000000000005', '0.0']
# ['EAFETQSGA', '0.11900000000000002', '0.0']
# ['DVSRPTAVV', '0.07949999999999996', '0.0']
# ['DVGCLLTDT', '-0.09290000000000002', '0.0']
# ['DTEFINKFL', '-0.02540000000000006', '0.0']
# ['DLNRMPTDM', '0.060300000000000034', '0.0']
# ['DLAARNVLV', '0.49040000000000006', '0.0']
# ['DAKRNSKSL', '-0.24349999999999994', '0.0']
# ['CIPSRSKML', '0.0652', '0.0']
# ['AVMFFPFWF', '0.4481', '0.0']
# ['ALYRRIQRR', '0.3315', '0.0']
# ['AFVRFSTDK', '-0.03750000000000001', '0.0']
# Saved averaged predictions to validation_avg.pred
# A3101; Outer validation set = 0, lambda = 0.02 epsilon = 0.01 PCC 0.69624 MSE 0.03591
# A3101; Outer validation set = 0, lambda = 0.02 epsilon = 0.04 PCC 0.67247 MSE 0.03893
# A3101; Outer validation set = 0, lambda = 0.02 epsilon = 0.08 PCC 0.62302 MSE 0.04604
# A3101; Outer validation set = 0, lambda = 0.08 epsilon = 0.01 PCC 0.69623 MSE 0.03590
# A3101; Outer validation set = 0, lambda = 0.08 epsilon = 0.04 PCC 0.67244 MSE 0.03893
# A3101; Outer validation set = 0, lambda = 0.08 epsilon = 0.08 PCC 0.62295 MSE 0.04604
# A3101; Outer validation set = 0, lambda = 0.1 epsilon = 0.01 PCC 0.69624 MSE 0.03590
# A3101; Outer validation set = 0, lambda = 0.1 epsilon = 0.04 PCC 0.67244 MSE 0.03893
# A3101; Outer validation set = 0, lambda = 0.1 epsilon = 0.08 PCC 0.62299 MSE 0.04604
#
# Best model for allele A3101 and Outer validation set ' 0 ', : lambda 0.02 epsilon 0.01 with correlation 0.69624
#
# A3101; Outer validation set = 1, lambda = 0.02 epsilon = 0.01 PCC 0.72150 MSE 0.03302
# A3101; Outer validation set = 1, lambda = 0.02 epsilon = 0.04 PCC 0.68881 MSE 0.03702
# A3101; Outer validation set = 1, lambda = 0.02 epsilon = 0.08 PCC 0.64276 MSE 0.04399
# A3101; Outer validation set = 1, lambda = 0.08 epsilon = 0.01 PCC 0.72151 MSE 0.03302
# A3101; Outer validation set = 1, lambda = 0.08 epsilon = 0.04 PCC 0.68881 MSE 0.03702
# A3101; Outer validation set = 1, lambda = 0.08 epsilon = 0.08 PCC 0.64271 MSE 0.04398
# A3101; Outer validation set = 1, lambda = 0.1 epsilon = 0.01 PCC 0.72154 MSE 0.03301
# A3101; Outer validation set = 1, lambda = 0.1 epsilon = 0.04 PCC 0.68879 MSE 0.03702
# A3101; Outer validation set = 1, lambda = 0.1 epsilon = 0.08 PCC 0.64272 MSE 0.04398
#
# Best model for allele A3101 and Outer validation set ' 1 ', : lambda 0.1 epsilon 0.01 with correlation 0.72154
#
# A3101; Outer validation set = 2, lambda = 0.02 epsilon = 0.01 PCC 0.73407 MSE 0.03170
# A3101; Outer validation set = 2, lambda = 0.02 epsilon = 0.04 PCC 0.71725 MSE 0.03414
# A3101; Outer validation set = 2, lambda = 0.02 epsilon = 0.08 PCC 0.68747 MSE 0.03863
# A3101; Outer validation set = 2, lambda = 0.08 epsilon = 0.01 PCC 0.73407 MSE 0.03170
# A3101; Outer validation set = 2, lambda = 0.08 epsilon = 0.04 PCC 0.71724 MSE 0.03414
# A3101; Outer validation set = 2, lambda = 0.08 epsilon = 0.08 PCC 0.68743 MSE 0.03862
# A3101; Outer validation set = 2, lambda = 0.1 epsilon = 0.01 PCC 0.73408 MSE 0.03170
# A3101; Outer validation set = 2, lambda = 0.1 epsilon = 0.04 PCC 0.71723 MSE 0.03414
# A3101; Outer validation set = 2, lambda = 0.1 epsilon = 0.08 PCC 0.68741 MSE 0.03862
#
# Best model for allele A3101 and Outer validation set ' 2 ', : lambda 0.1 epsilon 0.01 with correlation 0.73408
#
# A3101; Outer validation set = 3, lambda = 0.02 epsilon = 0.01 PCC 0.69870 MSE 0.03566
# A3101; Outer validation set = 3, lambda = 0.02 epsilon = 0.04 PCC 0.67033 MSE 0.03917
# A3101; Outer validation set = 3, lambda = 0.02 epsilon = 0.08 PCC 0.63222 MSE 0.04495
# A3101; Outer validation set = 3, lambda = 0.08 epsilon = 0.01 PCC 0.69868 MSE 0.03566
# A3101; Outer validation set = 3, lambda = 0.08 epsilon = 0.04 PCC 0.67033 MSE 0.03917
# A3101; Outer validation set = 3, lambda = 0.08 epsilon = 0.08 PCC 0.63220 MSE 0.04494
# A3101; Outer validation set = 3, lambda = 0.1 epsilon = 0.01 PCC 0.69872 MSE 0.03565
# A3101; Outer validation set = 3, lambda = 0.1 epsilon = 0.04 PCC 0.67032 MSE 0.03917
# A3101; Outer validation set = 3, lambda = 0.1 epsilon = 0.08 PCC 0.63219 MSE 0.04494
#
# Best model for allele A3101 and Outer validation set ' 3 ', : lambda 0.1 epsilon 0.01 with correlation 0.69872
#
# ['STLNFNNLR', '0.6652', '1.0']
# ['NMKPNFWSR', '0.6715', '1.0']
# ['KSISKSNAK', '0.5143', '1.0']
# ['ILQLIRHGR', '0.6456', '1.0']
# ['ALYRRIQRR', '0.7553000000000001', '1.0']
# ['RVIWMDAYK', '0.5582999999999999', '0.995779']
# ['SARNKLFKR', '0.7662', '0.979404']
# ['LSKWHTSAR', '0.7534000000000001', '0.972653']
# ['LLRHYYNKR', '0.6317', '0.95216']
# ['KTNDINVRR', '0.8631', '0.925638']
# ['ILSKIPYLR', '0.692', '0.913834']
# ['KSISSMTIR', '0.7755000000000001', '0.880569']
# ['ATSIYTIER', '0.6508', '0.869378']
# ['RTKLMSNIK', '0.4655', '0.861249']
# ['SFIISTLNK', '0.4487', '0.849366']
# ['KLMEEYLRR', '0.6845000000000001', '0.840873']
# ['HINTLIQYR', '0.7399', '0.833619']
# ['SLNRQTVSR', '0.5918', '0.817576']
# ['IINAHRIPK', '0.3953', '0.803837']
# ['MVNHSTYYV', '0.5046', '0.7841']
# ['LLGPGRPYK', '0.3436', '0.778379']
# ['VVFGILIKR', '0.6258', '0.770337']
# ['LMWNKQFIK', '0.5920000000000001', '0.763429']
# ['KLQARNIQK', '0.48950000000000005', '0.759689']
# ['NFIPIIYSK', '0.48629999999999995', '0.756465']
# ['YTKVVHYRK', '0.5855', '0.749713']
# ['TTYMDTFFR', '0.8489', '0.740568']
# ['LVKSYSLIR', '0.6692', '0.730742']
# ['VMHINSPFK', '0.44199999999999995', '0.723501']
# ['LLKILDNLR', '0.5833', '0.719095']
# ['RAFLLRHYY', '0.5826', '0.705723']
# ['KAFKNNLSR', '0.6877', '0.700914']
# ['IVFNLPVSK', '0.33229999999999993', '0.698145']
# ['CFLVKLKHR', '0.5961000000000001', '0.692101']
# ['IASKINNNR', '0.5587', '0.689347']
# ['IMSIGFEAR', '0.6115', '0.684841']
# ['IMPARFYPK', '0.5499999999999999', '0.674082']
# ['AALDGTFQR', '0.7477', '0.667837']
# ['VSLSAYIIR', '0.6647000000000001', '0.658539']
# ['QTVNICIFY', '0.2709', '0.37784']
# ['VFSFWLLCK', '0.3499', '0.374212']
# ['RCHDHYLCR', '0.5736000000000001', '0.370551']
# ['RFEAYGWQV', '0.35829999999999995', '0.368868']
# ['FSLESDSIK', '0.2658', '0.365317']
# ['VMTEGRHAV', '0.35089999999999993', '0.362426']
# ['ALRANSAVK', '0.3197', '0.358747']
# ['IMDKEQLLK', '0.23109999999999997', '0.350619']
# ['AMHYIRHRA', '0.43970000000000004', '0.346198']
# ['SAICSVVRR', '0.6334', '0.344711']
# ['STGPLHGCK', '0.3380000000000001', '0.341905']
# ['SSLVKNVNK', '0.4078', '0.340813']
# ['VIFYFISIY', '0.2732', '0.33869']
# ['VSDLYTSMR', '0.5173', '0.336577']
# ['STGESSILR', '0.5324', '0.334475']
# ['ILGGVLHTK', '0.29269999999999996', '0.332073']
# ['AVSEIQNNK', '0.29989999999999994', '0.328569']
# ['LSDENYLLK', '0.2537', '0.324184']
# ['VSAQNISFK', '0.3114', '0.320145']
# ['SVLDIISSK', '0.42769999999999997', '0.314193']
# ['NIVTDLENR', '0.33949999999999997', '0.310272']
# ['LSDIISAEK', '0.3352', '0.307295']
# ['ELTTVFIKY', '0.1689', '0.306083']
# ['KSDAKRNSK', '0.3862999999999999', '0.304706']
# ['KSSIKDSMY', '0.26949999999999996', '0.301973']
# ['FLWTQSLRR', '0.6189', '0.295422']
# ['TTIEDILPK', '0.3582', '0.293387']
# ['SSKGNCAIK', '0.35', '0.290972']
# ['FLELKRGIY', '0.1093', '0.288499']
# ['GVSENIFLK', '0.3744', '0.286613']
# ['QSYRQYRNY', '0.32999999999999996', '0.285993']
# ['ETITEKTFK', '0.27759999999999996', '0.282976']
# ['VVMAYVGIK', '0.36799999999999994', '0.278227']
# ['TSVSAKQLR', '0.6075', '0.273269']
# ['IIKHIYEQY', '0.2923', '0.271224']
# ['LSVETITEK', '0.2823', '0.262485']
# ['TMCTEETKR', '0.5259', '0.260566']
# ['LLKDLMPFV', '0.2969', '0.258638']
# ['ILKKLSSIK', '0.39109999999999995', '0.254516']
# ['LLDSIKMIY', '0.17179999999999995', '0.249885']
# ['AIKEVVMAY', '0.19119999999999998', '0.245361']
# ['FITKEIKNR', '0.4526', '0.243336']
# ['ALWEIQQVV', '0.2665', '0.239136']
# ['LFSKNILKY', '0.21090000000000003', '0.236098']
# ['MVDELVTRK', '0.28409999999999996', '0.234682']
# ['YAHINALEY', '0.11309999999999999', '0.229571']
# ['YSKLTKDRK', '0.3181', '0.226241']
# ['STLLTWHMH', '0.3027', '0.222696']
# ['KSLGIDQIW', '0.2447', '0.219401']
# ['YMHGSIHEV', '0.27630000000000005', '0.216488']
# ['YLFNQHIKK', '0.34329999999999994', '0.214322']
# ['ELENKKVEY', '0.06689999999999999', '0.21332']
# ['PVLTSLFNK', '0.4313', '0.210856']
# ['EQQQSFMPK', '0.2641', '0.208076']
# ['VVISKKDTY', '0.19240000000000002', '0.204012']
# ['LMYALEPRK', '0.3359', '0.201716']
# ['YSKFWYLEH', '0.33230000000000004', '0.195715']
# ['IIGPMFSGK', '0.26469999999999994', '0.191148']
# ['AQIDNYNKF', '0.1894', '0.188728']
# ['NFEALEATK', '0.2375', '0.185243']
# ['TLMNVITLV', '0.2965', '0.183744']
# ['VSVDAMIHK', '0.27290000000000003', '0.179857']
# ['KSPLPSLEY', '0.25830000000000003', '0.176711']
# ['GIEFADNDR', '0.2609', '0.174723']
# ['SVLCVKKFY', '0.2683', '0.16958']
# ['VVNYDNSTK', '0.3197', '0.168298']
# ['GTEMFRHGY', '0.3046', '0.167317']
# ['IFMRDWNSK', '0.31839999999999996', '0.163547']
# ['KSRCGSLGY', '0.3479999999999999', '0.161732']
# ['MSDIFHALV', '0.312', '0.157903']
# ['ILAALFMYY', '0.2963', '0.155516']
# ['NLEMIDERK', '0.16409999999999997', '0.153916']
# ['KMSTDNAVY', '0.3268', '0.151288']
# ['VIVVPVIDR', '0.3632', '0.149567']
# ['SISGKYDIK', '0.1795', '0.14875']
# ['LLYILFLVK', '0.45829999999999993', '0.14875']
# ['GTGSGVSSK', '0.2491', '0.14875']
# ['ANFQSSMTK', '0.26249999999999996', '0.14875']
# ['AIFQSSMTA', '0.08810000000000001', '0.14875']
# ['AIITPVVFY', '0.2103', '0.148526']
# ['SSPPIPMSR', '0.5534', '0.145266']
# ['LVVISVIFY', '0.1814', '0.142458']
# ['DINVIGLIV', '0.0954', '0.141701']
# ['KILSDENYL', '0.21800000000000003', '0.137424']
# ['SIIIPFIAY', '0.24659999999999999', '0.135916']
# ['SLSAYIIRV', '0.2214', '0.131369']
# ['PLHILASNK', '0.27149999999999996', '0.127882']
# ['QLMYALEPR', '0.5627', '0.126168']
# ['VTLDFTKFH', '0.34199999999999997', '0.123532']
# ['CCNWLDRCR', '0.3882', '0.120906']
# ['LIVSLCPTK', '0.268', '0.116526']
# ['ITSTKTIEY', '0.1789', '0.110681']
# ['FAEESYTYY', '0.22499999999999998', '0.107502']
# ['CVDIFTEGK', '0.17889999999999998', '0.103597']
# ['TIAGGVCYY', '0.1608', '0.098142']
# ['TTGRTSLPK', '0.39170000000000005', '0.094424']
# ['DSLLITNTK', '0.289', '0.091411']
# ['LLALQQLEV', '0.0457', '0.089079']
# ['ICKMPLPTK', '0.2585', '0.085589']
# ['YVRGYLRGY', '0.16169999999999995', '0.084687']
# ['YRYLRHGKL', '0.07359999999999998', '0.084687']
# ['YQRPFGGQS', '0.13779999999999998', '0.084687']
# ['YPAEITLTW', '0.010999999999999996', '0.084687']
# ['YLKKWLNSF', '0.1724', '0.084687']
# ['YLDDPDLKY', '-0.006600000000000009', '0.084687']
# ['YIALGRARV', '0.11440000000000002', '0.084687']
# ['YGLGSTPLY', '0.0595', '0.084687']
# ['YFSDVSAPV', '0.2216', '0.084687']
# ['YAEISFMLW', '0.1437', '0.084687']
# ['WSFLEDRVY', '0.0908', '0.084687']
# ['WMQELRAGA', '0.23469999999999996', '0.084687']
# ['WCRVGRGTI', '0.010700000000000008', '0.084687']
# ['VVPLYDTPL', '0.08579999999999997', '0.084687']
# ['VRDPKTSEI', '-0.08000000000000002', '0.084687']
# ['VQIPEKKCF', '-0.011399999999999993', '0.084687']
# ['VPRVHNQPQ', '0.04290000000000001', '0.084687']
# ['VNGVKGIQF', '0.0706', '0.084687']
# ['VMGGNAAEA', '-0.011000000000000003', '0.084687']
# ['VLLEARQAY', '0.19879999999999998', '0.084687']
# ['VGYVDDTQF', '0.07900000000000001', '0.084687']
# ['TTTLEETKF', '0.0645', '0.084687']
# ['TQDLFLPFY', '0.25279999999999997', '0.084687']
# ['TPKGPKVKY', '0.12380000000000001', '0.084687']
# ['THADVPVVL', '0.0673', '0.084687']
# ['SYGNANVSF', '0.13480000000000003', '0.084687']
# ['SSMNSDAAY', '0.3049', '0.084687']
# ['SRWGYQVKH', '0.1482', '0.084687']
# ['SQLEMCEKY', '0.13349999999999995', '0.084687']
# ['SPRTLNAWV', '0.1101', '0.084687']
# ['SLAIDAYPL', '0.1308', '0.084687']
# ['SEGDDDGSR', '0.246', '0.084687']
# ['RVDFCGKGY', '0.14240000000000003', '0.084687']
# ['RRRQWASCM', '-0.08360000000000001', '0.084687']
# ['RRGPEQTQG', '-0.1059', '0.084687']
# ['RPVSPGKDI', '-0.08679999999999999', '0.084687']
# ['RPQLGVGDV', '0.027299999999999984', '0.084687']
# ['RPLLARMPE', '0.2672', '0.084687']
# ['RMYGISPWT', '0.2123', '0.084687']
# ['RKAGVNQAK', '0.2012', '0.084687']
# ['RERIRYFHY', '0.3909', '0.084687']
# ['QTSTLYDFY', '0.2507', '0.084687']
# ['QLQCHQIAI', '0.14109999999999998', '0.084687']
# ['PTKCGENLY', '0.11750000000000001', '0.084687']
# ['PPSGKGGNY', '-0.06530000000000001', '0.084687']
# ['PLRNDGNRF', '0.03219999999999999', '0.084687']
# ['NSDPEFNVL', '-0.0175', '0.084687']
# ['NQATTKTTF', '0.11309999999999999', '0.084687']
# ['NNKSRLVAF', '0.2547', '0.084687']
# ['NILVAGNLI', '-0.0214', '0.084687']
# ['MRIPVERTL', '0.0046', '0.084687']
# ['MEIYIWDHD', '0.03440000000000001', '0.084687']
# ['LTLKPCHAL', '0.2735', '0.084687']
# ['LSDDAVVCY', '0.02090000000000001', '0.084687']
# ['LPRWPPPQL', '0.0644', '0.084687']
# ['LMPLARFWL', '0.21619999999999998', '0.084687']
# ['LLIDDSFSS', '0.10149999999999999', '0.084687']
# ['LIFPAFFLC', '0.23729999999999998', '0.084687']
# ['LADTSLSGY', '0.1201', '0.084687']
# ['KTNFQNHKG', '0.31859999999999994', '0.084687']
# ['KRVDWSVEY', '0.1431', '0.084687']
# ['KNDAVYIGY', '0.1901', '0.084687']
# ['KIISEIGQL', '0.23199999999999998', '0.084687']
# ['KGGEAQFLV', '0.2461', '0.084687']
# ['IVLLCYGGW', '0.14059999999999997', '0.084687']
# ['ITTQWHLDM', '0.12250000000000003', '0.084687']
# ['ITDVQDMDP', '-0.08310000000000001', '0.084687']
# ['ISNYICVAW', '0.2302', '0.084687']
# ['ISDYDYYRY', '0.2383', '0.084687']
# ['AEDMLNPNY', '0.0425', '0.084687']
# ['AAGLPAIFV', '0.0916', '0.084687']
# ['AIILHQQQK', '0.2961', '0.081986']
# ['IVPEFAKQY', '-0.0591', '0.078889']
# ['TCQGSDDIR', '0.24489999999999998', '0.074342']
# ['SVGTGILFM', '0.23030000000000003', '0.072273']
# ['SHLGPQFCK', '0.2359', '0.066897']
# ['PVNRPIDWK', '0.22749999999999998', '0.064063']
# ['ALKAYFTAK', '0.5096999999999999', '0.060786']
# ['VCSFYADPK', '0.05379999999999999', '0.05604']
# ['DTIESAKTK', '0.07730000000000001', '0.048105']
# ['NSSAVVDNK', '0.1457', '0.04541']
# ['MLKLFTHDI', '0.19910000000000003', '0.041582']
# ['NTIVFGIYK', '0.4041', '0.037206']
# ['VVKWKRDEH', '0.3042', '0.033381']
# ['DTSNNIAEY', '0.12710000000000002', '0.031297']
# ['DAKNDDWKK', '0.2319', '0.028649']
# ['ALDGTFQRK', '0.26239999999999997', '0.025522']
# ['IVNEHDIKY', '0.11639999999999998', '0.020781']
# ['GLENGLNYI', '0.1174', '0.012187']
# ['CSKHMDARY', '0.30670000000000003', '0.009402']
# ['YLPEVISTI', '0.019100000000000013', '0.001635']
# ['YVKNGTKGK', '0.23819999999999997', '0.0']
# ['YLSDSDNIK', '0.17099999999999999', '0.0']
# ['YITDDSDDY', '-0.062', '0.0']
# ['WPISAILWF', '0.08789999999999999', '0.0']
# ['VVKDDPDHY', '0.09609999999999999', '0.0']
# ['VSYEVFDDY', '0.1161', '0.0']
# ['VAGTGVQFY', '0.1768', '0.0']
# ['TLDTMDDMK', '0.08999999999999998', '0.0']
# ['STTDAEACY', '0.1406', '0.0']
# ['SITPNNLNK', '0.32530000000000003', '0.0']
# ['SAVVDNKLK', '0.1892', '0.0']
# ['QILDNAAKY', '0.062400000000000004', '0.0']
# ['PIINTHSFY', '0.23319999999999996', '0.0']
# ['NSKYSYELY', '0.2279', '0.0']
# ['MPASWVMRI', '0.06769999999999998', '0.0']
# ['LPIDKCSRI', '0.047999999999999994', '0.0']
# ['LFHGGEPIK', '0.20689999999999997', '0.0']
# ['IPRRNVATL', '0.11259999999999999', '0.0']
# ['IFPGDKTSY', '0.01979999999999999', '0.0']
# ['HSKRKCDEL', '0.22150000000000003', '0.0']
# ['GTIAGGVCY', '0.10900000000000001', '0.0']
# ['GAVVKSDNK', '0.2207', '0.0']
# ['FPRGQGVPI', '-0.0476', '0.0']
# ['FISDNKKEY', '0.028100000000000007', '0.0']
# ['EVDPIGHLY', '0.1719', '0.0']
# ['EQGDIALAL', '0.038700000000000005', '0.0']
# ['ELGFNYPEY', '0.0257', '0.0']
# ['EIITGNKVK', '0.0897', '0.0']
# ['DVLPFDIKY', '0.07289999999999999', '0.0']
# ['DSPLTLLIK', '0.1928', '0.0']
# ['DIICEDAMY', '-0.08869999999999999', '0.0']
# ['CTDESRDRK', '0.20249999999999999', '0.0']
# ['ASTTENAAY', '0.21399999999999997', '0.0']
# Saved averaged predictions to validation_avg.pred
